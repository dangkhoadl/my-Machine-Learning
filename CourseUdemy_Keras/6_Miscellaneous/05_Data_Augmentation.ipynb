# %% [markdown]
# ## Data Augmentation
# - Create more data based on the original data
#
# ### Images
# + Shift/Translation
# + Shear
# + Flip
# + Rotate
# + Crop
# + Change the aspect ratio
# + Zoom in/out
# + Add noises
# + Change color (to Black and White...)
# ...
#
# ### Sounds
# + Change pitch
# + Change speed
# + Add background noise
# + Distortion, echo
# ...
#
# ### Text
# + Use synonyms

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ### Original Data

# %%
from PIL import Image

orignal_data = Image.open('./generator/class 0/squirrel.jpeg')
plt.imshow(orignal_data)

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

generator = ImageDataGenerator(rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range = 20,
                               shear_range = 0.3,
                               zoom_range = 0.3,
                               horizontal_flip = True)
# Out:
# Using TensorFlow backend.

# %%
train_data = generator.flow_from_directory(
    './generator',
    target_size = (128, 128),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# ## Plot Augmented Data

# %%
img, label = train_data[0]
display(img.shape)
plt.imshow(img[0])
# Out:
# (1, 128, 128, 3)

# %%
plt.figure(figsize=(12, 12))
for i in range(16):
    img, label = train_data.next()
    plt.subplot(4, 4, i+1)
    plt.imshow(img[0])
