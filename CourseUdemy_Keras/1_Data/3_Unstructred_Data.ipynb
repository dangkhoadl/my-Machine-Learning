# %% [markdown]
# # Unstructured Data
# - Images
# - Sounds
# - Texts
#
#     -> Need Feature extraction
#
#     -> Prefer Deep learning

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Images

# %%
from PIL import Image

# %%
img = Image.open('iss.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x435 at 0x7F89C79FB588>

# %%
imgarray = np.asarray(img)
imgarray.shape
# Out:
# (435, 640, 3)

# %%
# unroll the image -> lost 2D, 3D info
imgarray.ravel().shape
# Out:
# (835200,)

# %% [markdown]
# ## Sounds

# %%
from scipy.io import wavfile
from IPython.display import Audio

# %%
rate, snd = wavfile.read(filename='sms.wav')

# %%
Audio(data=snd, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(snd)
# Out:
# 110250

# %%
# Time representation: x = time, y = Amplitude
plt.plot(snd);

# %%
# Frequency Domain - FFT
plt.specgram(snd, NFFT=1024, Fs=44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5,0,'Time (s)')
