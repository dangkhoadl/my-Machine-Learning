# %%
import pandas as pd
import numpy as np

original = pd.DataFrame({
    'one': pd.Series(np.random.randint(-10, 10, (4,)), index=[2,3,5,8]),
    'two': pd.Series(np.random.randint(-10, 10, (4,)), index=[1,2,3,4]),
    'three': pd.Series(np.random.randint(-10, 10, (7,)), index=[2,3,4,5,6,7,8]),
    'four': pd.Series(np.random.randint(-10, 10, (7,)), index=[1,2,3,4,5,6,7]),
    'five': pd.Series(np.random.randint(-10, 10, (9,)))
    })

display(original)
# Out:
#    one  two  three  four  five
# 0  NaN  NaN    NaN   NaN     4
# 1  NaN -7.0    NaN  -7.0     6
# 2 -1.0  7.0   -5.0  -5.0    -1
# 3 -1.0 -2.0    3.0  -5.0     2
# 4  NaN -4.0   -2.0  -6.0     7
# 5  6.0  NaN    9.0  -4.0     7
# 6  NaN  NaN   -2.0   1.0    -4
# 7  NaN  NaN    3.0  -8.0    -1
# 8  5.0  NaN   -1.0   NaN     2

# %% [markdown]
# # Deep copy
# - If `df = original` $\to$ change in `df` = change in `original`

# %%
df = original.copy()

# %% [markdown]
# # Rows
# #### Drop rows

# %%
df.drop(4, inplace=True)
df
# Out:
#    one  two  three  four  five
# 0  NaN  NaN    NaN   NaN     4
# 1  NaN -7.0    NaN  -7.0     6
# 2 -1.0  7.0   -5.0  -5.0    -1
# 3 -1.0 -2.0    3.0  -5.0     2
# 5  6.0  NaN    9.0  -4.0     7
# 6  NaN  NaN   -2.0   1.0    -4
# 7  NaN  NaN    3.0  -8.0    -1
# 8  5.0  NaN   -1.0   NaN     2

# %%
df.drop([2,5,6], inplace=True)
df
# Out:
#    one  two  three  four  five
# 0  NaN  NaN    NaN   NaN     4
# 1  NaN -7.0    NaN  -7.0     6
# 3 -1.0 -2.0    3.0  -5.0     2
# 7  NaN  NaN    3.0  -8.0    -1
# 8  5.0  NaN   -1.0   NaN     2

# %% [markdown]
# #### Add rows

# %%
df.loc[2] = [1, 2, 3, 4, 10]
df
# Out:
#    one  two  three  four  five
# 0  NaN  NaN    NaN   NaN     4
# 1  NaN -7.0    NaN  -7.0     6
# 3 -1.0 -2.0    3.0  -5.0     2
# 7  NaN  NaN    3.0  -8.0    -1
# 8  5.0  NaN   -1.0   NaN     2
# 2  1.0  2.0    3.0   4.0    10

# %% [markdown]
# #### Reset index

# %%
df.reset_index(inplace=True)
df
# Out:
#    index  one  two  three  four  five
# 0      0  NaN  NaN    NaN   NaN     4
# 1      1  NaN -7.0    NaN  -7.0     6
# 2      3 -1.0 -2.0    3.0  -5.0     2
# 3      7  NaN  NaN    3.0  -8.0    -1
# 4      8  5.0  NaN   -1.0   NaN     2
# 5      2  1.0  2.0    3.0   4.0    10

# %% [markdown]
# # Cols
# #### Drop cols

# %%
df.drop('index', axis=1, inplace=True)
df
# Out:
#    one  two  three  four  five
# 0  NaN  NaN    NaN   NaN     4
# 1  NaN -7.0    NaN  -7.0     6
# 2 -1.0 -2.0    3.0  -5.0     2
# 3  NaN  NaN    3.0  -8.0    -1
# 4  5.0  NaN   -1.0   NaN     2
# 5  1.0  2.0    3.0   4.0    10

# %%
df.drop(['two', 'five'], axis=1, inplace=True)
df
# Out:
#    one  three  four
# 0  NaN    NaN   NaN
# 1  NaN    NaN  -7.0
# 2 -1.0    3.0  -5.0
# 3  NaN    3.0  -8.0
# 4  5.0   -1.0   NaN
# 5  1.0    3.0   4.0

# %% [markdown]
# #### Add cols

# %%
df['six'] = df['three'] + df['one']
df
# Out:
#    one  three  four  six
# 0  NaN    NaN   NaN  NaN
# 1  NaN    NaN  -7.0  NaN
# 2 -1.0    3.0  -5.0  2.0
# 3  NaN    3.0  -8.0  NaN
# 4  5.0   -1.0   NaN  4.0
# 5  1.0    3.0   4.0  4.0

# %%
df['seven'] = -10
df
# Out:
#    one  three  four  six  seven
# 0  NaN    NaN   NaN  NaN    -10
# 1  NaN    NaN  -7.0  NaN    -10
# 2 -1.0    3.0  -5.0  2.0    -10
# 3  NaN    3.0  -8.0  NaN    -10
# 4  5.0   -1.0   NaN  4.0    -10
# 5  1.0    3.0   4.0  4.0    -10

# %%
df['eights'] = df['one'].apply(lambda x: x*2)
df
# Out:
#    one  three  four  six  seven  eights
# 0  NaN    NaN   NaN  NaN    -10     NaN
# 1  NaN    NaN  -7.0  NaN    -10     NaN
# 2 -1.0    3.0  -5.0  2.0    -10    -2.0
# 3  NaN    3.0  -8.0  NaN    -10     NaN
# 4  5.0   -1.0   NaN  4.0    -10    10.0
# 5  1.0    3.0   4.0  4.0    -10     2.0

# %%
df.insert(loc=0, column='Count', value=1)
df
# Out:
#    Count  one  three  four  six  seven  eights
# 0      1  NaN    NaN   NaN  NaN    -10     NaN
# 1      1  NaN    NaN  -7.0  NaN    -10     NaN
# 2      1 -1.0    3.0  -5.0  2.0    -10    -2.0
# 3      1  NaN    3.0  -8.0  NaN    -10     NaN
# 4      1  5.0   -1.0   NaN  4.0    -10    10.0
# 5      1  1.0    3.0   4.0  4.0    -10     2.0

# %% [markdown]
# #### Change col order + drop

# %%
df = df[['one', 'seven', 'six']]
df
# Out:
#    one  seven  six
# 0  NaN    -10  NaN
# 1  NaN    -10  NaN
# 2 -1.0    -10  2.0
# 3  NaN    -10  NaN
# 4  5.0    -10  4.0
# 5  1.0    -10  4.0

# %% [markdown]
# # Handling NaN

# %% [markdown]
# #### Drop all rows

# %%
df = original.copy()

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#    one  two  three  four  five
# 0 -1.0  7.0   -5.0  -5.0    -1
# 1 -1.0 -2.0    3.0  -5.0     2

# %% [markdown]
# #### Drop all cols

# %%
df = original.copy()

df.dropna(axis=1, inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#    five
# 0     4
# 1     6
# 2    -1
# 3     2
# 4     7
# 5     7
# 6    -4
# 7    -1
# 8     2

# %% [markdown]
# #### Fill with

# %%
df = original.copy()

# %%
df['one'].fillna(df['one'].mean(), inplace=True)
df['two'].fillna(5, inplace=True)
df['three'].fillna(df['three'].median(), inplace=True)
df
# Out:
#     one  two  three  four  five
# 0  2.25  5.0   -1.0   NaN     4
# 1  2.25 -7.0   -1.0  -7.0     6
# 2 -1.00  7.0   -5.0  -5.0    -1
# 3 -1.00 -2.0    3.0  -5.0     2
# 4  2.25 -4.0   -2.0  -6.0     7
# 5  6.00  5.0    9.0  -4.0     7
# 6  2.25  5.0   -2.0   1.0    -4
# 7  2.25  5.0    3.0  -8.0    -1
# 8  5.00  5.0   -1.0   NaN     2
