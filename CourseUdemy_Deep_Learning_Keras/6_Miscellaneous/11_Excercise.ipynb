# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ## Exercise
#
# This is a very long and complex exercise, that should give you an idea of a real world scenario. Feel free to look at the solution if you feel lost. Also, feel free to run this on Floyd with a GPU, in which case you don't need to download the data.
#
# If you are running this locally, download and unpack the male/female pictures from [here](https://www.dropbox.com/s/nov493om2jmh2gp/male_female.tgz?dl=0). These images and labels were obtained from [Crowdflower](https://www.crowdflower.com/data-for-everyone/).
#
# Your goal is to build an image classifier that will recognize the gender of a person from pictures.
#
# - Have a look at the directory structure and inspect a couple of pictures
# - Design a model that will take a color image of size 64x64 as input and return a binary output (female=0/male=1)
# - Feel free to introduce any regularization technique in your model (Dropout, Batch Normalization, Weight Regularization)
# - Compile your model with an optimizer of your choice
# - Using `ImageDataGenerator`, define a train generator that will augment your images with some geometric transformations. Feel free to choose the parameters that make sense to you.
# - Define also a test generator, whose only purpose is to rescale the pixels by 1./255
# - use the function `flow_from_directory` to generate batches from the train and test folders. Make sure you set the `target_size` to 64x64.
# - Use the `model.fit_generator` function to fit the model on the batches generated from the ImageDataGenerator. Since you are streaming and augmenting the data in real time you will have to decide how many batches make an epoch and how many epochs you want to run
# - Train your model (you should get to at least 85% accuracy)
# - Once you are satisfied with your training, check a few of the misclassified pictures. Are those sensible errors?

# %% [markdown]
# #### Download data

# %%
# if you are running this on floydhub.com, execute this cell and skip the next
data_path = '/input'

# %%
# If you are running this locally

# !mkdir -p ./data
# !wget https://www.dropbox.com/s/nov493om2jmh2gp/male_female.tgz?dl=0 -O ./data/male_female.tgz > /tmp/temp.outerr 2>&1
# !tar -xzvf ./data/male_female.tgz > /tmp/temp.outerr 2>&1
# !rm ./data/male_female.tgz

# data_path = './data'

# %%
from PIL import Image

orignal_data_female = Image.open(data_path + '/train/0_female/153546-large.jpg')
orignal_data_male = Image.open(data_path + '/train/1_male/3642-large.jpg')

plt.subplot(1,2,1)
plt.imshow(orignal_data_female)
plt.subplot(1,2,2)
plt.imshow(orignal_data_male)

# %% [markdown]
# #### Augment Data

# %%
from keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range = 10,
                               shear_range = 0.2,
                               zoom_range = 0.2,
                               horizontal_flip = True)

test_gen = ImageDataGenerator(rescale = 1./255)
# Out:
# Using TensorFlow backend.

# %%
train = train_gen.flow_from_directory(data_path + '/train',
                                      target_size = (64, 64),
                                      batch_size = 16,
                                      class_mode = 'binary')

test = test_gen.flow_from_directory(data_path + '/test',
                                    target_size = (64, 64),
                                    batch_size = 16,
                                    class_mode = 'binary')
# Out:
# Found 11663 images belonging to 2 classes.
# Found 2920 images belonging to 2 classes.

# %%
img, label = train.next()
print(img.shape)
print(label.shape)
# Out:
# (16, 64, 64, 3)
# (16,)

# %%
plt.figure(figsize=(16, 16))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(img[i])
    plt.gca().set_title('{}'.format('Male' if int(label[i])==1 else 'Female'))

# %% [markdown]
# #### Model

# %%
from keras.layers import \
    Conv2D, \
    MaxPooling2D, \
    Flatten, \
    BatchNormalization, \
    Dense
from keras.models import Sequential
import keras.backend as K

K.clear_session()

model = Sequential()

# Feature Extraction layers
model.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(BatchNormalization())

# Flatten layer
model.add(Flatten())

# Fully connected layers
model.add(Dense(128, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# Compile
model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 31, 31, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 352,129
# Trainable params: 351,809
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #### Train

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)

# !mkdir -p ./weights
checkpoint = ModelCheckpoint('./weights/male_female_weights.h5', save_best_only=True)

# %%
history = model.fit_generator(
    train,
    steps_per_epoch=800,
    epochs=200,
    validation_data=test,
    validation_steps=200,
    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 800/800 [==============================] - 220s 276ms/step - loss: 0.6628 - acc: 0.6742 - val_loss: 0.5187 - val_acc: 0.7353
# Epoch 2/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.4957 - acc: 0.7510 - val_loss: 0.4644 - val_acc: 0.7726
# Epoch 3/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.4549 - acc: 0.7756 - val_loss: 0.4721 - val_acc: 0.7597
# Epoch 4/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.4325 - acc: 0.7932 - val_loss: 0.4373 - val_acc: 0.7929
# Epoch 5/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.4069 - acc: 0.8063 - val_loss: 0.4023 - val_acc: 0.8086
# Epoch 6/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3871 - acc: 0.8172 - val_loss: 0.4074 - val_acc: 0.8095
# Epoch 7/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.3773 - acc: 0.8214 - val_loss: 0.4218 - val_acc: 0.7851
# Epoch 8/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3554 - acc: 0.8336 - val_loss: 0.4697 - val_acc: 0.7660
# Epoch 9/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3488 - acc: 0.8373 - val_loss: 0.3887 - val_acc: 0.8076
# Epoch 10/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3327 - acc: 0.8443 - val_loss: 0.3913 - val_acc: 0.8045
# Epoch 11/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3199 - acc: 0.8519 - val_loss: 0.3355 - val_acc: 0.8396
# Epoch 12/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3102 - acc: 0.8544 - val_loss: 0.3300 - val_acc: 0.8456
# Epoch 13/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.3027 - acc: 0.8582 - val_loss: 0.3306 - val_acc: 0.8452
# Epoch 14/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.2962 - acc: 0.8673 - val_loss: 0.3195 - val_acc: 0.8493
# Epoch 15/200
# 800/800 [==============================] - 220s 275ms/step - loss: 0.2893 - acc: 0.8648 - val_loss: 0.3630 - val_acc: 0.8311
# Epoch 16/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.2842 - acc: 0.8719 - val_loss: 0.3196 - val_acc: 0.8515
# Epoch 17/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.2737 - acc: 0.8771 - val_loss: 0.3143 - val_acc: 0.8521
# Epoch 18/200
# 800/800 [==============================] - 221s 276ms/step - loss: 0.2671 - acc: 0.8819 - val_loss: 0.2969 - val_acc: 0.8578
# Epoch 19/200
# 800/800 [==============================] - 220s 274ms/step - loss: 0.2677 - acc: 0.8784 - val_loss: 0.3972 - val_acc: 0.8023
# Epoch 20/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2612 - acc: 0.8837 - val_loss: 0.3163 - val_acc: 0.8618
# Epoch 21/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2631 - acc: 0.8798 - val_loss: 0.3054 - val_acc: 0.8656
# Epoch 22/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2502 - acc: 0.8873 - val_loss: 0.3056 - val_acc: 0.8672
# Epoch 23/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2473 - acc: 0.8879 - val_loss: 0.2817 - val_acc: 0.8672
# Epoch 24/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2412 - acc: 0.8935 - val_loss: 0.2961 - val_acc: 0.8634
# Epoch 25/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2431 - acc: 0.8953 - val_loss: 0.2843 - val_acc: 0.8690
# Epoch 26/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.2329 - acc: 0.8973 - val_loss: 0.2920 - val_acc: 0.8631
# Epoch 27/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2441 - acc: 0.8933 - val_loss: 0.3062 - val_acc: 0.8565
# Epoch 28/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.2288 - acc: 0.8994 - val_loss: 0.3370 - val_acc: 0.8578
# Epoch 29/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2266 - acc: 0.9041 - val_loss: 0.3229 - val_acc: 0.8584
# Epoch 30/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2223 - acc: 0.9038 - val_loss: 0.2978 - val_acc: 0.8662
# Epoch 31/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2243 - acc: 0.9019 - val_loss: 0.2840 - val_acc: 0.8684
# Epoch 32/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.2169 - acc: 0.9042 - val_loss: 0.2894 - val_acc: 0.8656
# Epoch 33/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2153 - acc: 0.9050 - val_loss: 0.3542 - val_acc: 0.8493
# Epoch 34/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2163 - acc: 0.9064 - val_loss: 0.3123 - val_acc: 0.8672
# Epoch 35/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2106 - acc: 0.9084 - val_loss: 0.2917 - val_acc: 0.8703
# Epoch 36/200
# 800/800 [==============================] - 219s 274ms/step - loss: 0.2094 - acc: 0.9113 - val_loss: 0.3815 - val_acc: 0.8412
# Epoch 37/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.2050 - acc: 0.9111 - val_loss: 0.2943 - val_acc: 0.8722
# Epoch 38/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.2043 - acc: 0.9111 - val_loss: 0.3200 - val_acc: 0.8571
# Epoch 39/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.1986 - acc: 0.9166 - val_loss: 0.2921 - val_acc: 0.8712
# Epoch 40/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.2035 - acc: 0.9129 - val_loss: 0.3177 - val_acc: 0.8659
# Epoch 41/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.1971 - acc: 0.9135 - val_loss: 0.3339 - val_acc: 0.8603
# Epoch 42/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.1889 - acc: 0.9206 - val_loss: 0.2908 - val_acc: 0.8694
# Epoch 43/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.1894 - acc: 0.9195 - val_loss: 0.3219 - val_acc: 0.8712
# Epoch 44/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.1868 - acc: 0.9208 - val_loss: 0.2969 - val_acc: 0.8722
# Epoch 45/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.1848 - acc: 0.9212 - val_loss: 0.3026 - val_acc: 0.8719
# Epoch 46/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.1861 - acc: 0.9185 - val_loss: 0.3021 - val_acc: 0.8753
# Epoch 47/200
# 800/800 [==============================] - 219s 273ms/step - loss: 0.1893 - acc: 0.9215 - val_loss: 0.3233 - val_acc: 0.8518
# Epoch 48/200
# 800/800 [==============================] - 218s 273ms/step - loss: 0.1875 - acc: 0.9209 - val_loss: 0.3195 - val_acc: 0.8675
# Epoch 00048: early stopping

# %%
historydf = pd.DataFrame(history.history, index=history.epoch)
historydf.plot();

# %% [markdown]
# #### Evaluate

# %%
from keras.models import load_model

model = load_model('./weights/male_female_weights.h5')

# %%
from itertools import islice

X_test = []
y_test = []
for ts in islice(test, 50):
    X_test.append(ts[0])
    y_test.append(ts[1])

X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# %%
y_pred = model.predict_classes(X_test).ravel()

# %%
print('Accuracy: {} %'.format(
    float(len(np.argwhere(y_test==y_pred).ravel()))*100.0 / len(y_test)))
# Out:
# Accuracy: 85.75 %

# %% [markdown]
# #### Sample

# %%
img, label = test.next()
pred = model.predict_classes(img).ravel()

plt.figure(figsize=(16, 16))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(img[i])
    plt.gca().set_title(
        '''Predict: {}\nTrue Label: {}'''.format(
            'Male' if int(pred[i])==1 else 'Female',
            'Male' if int(label[i])==1 else 'Female'))
